# %% [raw]
# ---
# description: API details
# output-file: ghtop.html
# title: ghtop API
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
evts = load_sample_events()

# %%
#|output: asis
#| echo: false
show_doc(get_sparklines)
# Out:
# ---
#
# [source](https://github.com/fastai/ghtop/tree/master/blob/master/ghtop/ghtop.py#L24){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_sparklines
#
# >      get_sparklines ()

# %% [markdown]
# When creating `GhApi` we can pass a callback which will be called after each API operation. In this case, we use it to warn the user when their quota is getting low.

# %%
def limit_cb(rem,quota):
    "Callback to warn user when close to using up hourly quota"
    w='WARNING '*7
    if rem < 1000: print(f"{w}\nRemaining calls: {rem} out of {quota}\n{w}", file=sys.stderr)

# %%
#|output: asis
#| echo: false
show_doc(limit_cb)
# Out:
# ---
#
# [source](https://github.com/fastai/ghtop/tree/master/blob/master/ghtop/ghtop.py#L46){target="_blank" style="float:right; font-size:smaller"}
#
# ### limit_cb
#
# >      limit_cb (rem, quota)
#
# Callback to warn user when close to using up hourly quota

# %%
#|output: asis
#| echo: false
show_doc(pct_comp)
# Out:
# ---
#
# [source](https://github.com/fastai/ghtop/tree/master/blob/master/ghtop/ghtop.py#L52){target="_blank" style="float:right; font-size:smaller"}
#
# ### pct_comp
#
# >      pct_comp (api)

# %%
#|output: asis
#| echo: false
show_doc(tail_events)
# Out:
# ---
#
# [source](https://github.com/fastai/ghtop/tree/master/blob/master/ghtop/ghtop.py#L55){target="_blank" style="float:right; font-size:smaller"}
#
# ### tail_events
#
# >      tail_events (evt, api)
#
# Print events from `fetch_events` along with a counter of push events

# %%
#|output: asis
#| echo: false
show_doc(watch_users)
# Out:
# ---
#
# [source](https://github.com/fastai/ghtop/tree/master/blob/master/ghtop/ghtop.py#L77){target="_blank" style="float:right; font-size:smaller"}
#
# ### watch_users
#
# >      watch_users (evts, api)
#
# Print a table of the users with the most events

# %%
#|output: asis
#| echo: false
show_doc(quad_logs)
# Out:
# ---
#
# [source](https://github.com/fastai/ghtop/tree/master/blob/master/ghtop/ghtop.py#L105){target="_blank" style="float:right; font-size:smaller"}
#
# ### quad_logs
#
# >      quad_logs (evts, api)
#
# Print 4 panels, showing most recent issues, commits, PRs, and releases

# %%
#|output: asis
#| echo: false
show_doc(simple)
# Out:
# ---
#
# [source](https://github.com/fastai/ghtop/tree/master/blob/master/ghtop/ghtop.py#L124){target="_blank" style="float:right; font-size:smaller"}
#
# ### simple
#
# >      simple (evts, api)

# %%
#|output: asis
#| echo: false
show_doc(main)
# Out:
# ---
#
# [source](https://github.com/fastai/ghtop/tree/master/blob/master/ghtop/ghtop.py#L148){target="_blank" style="float:right; font-size:smaller"}
#
# ### main
#
# >      main (mode:_OpModes<Operationmodetorun>,
# >            include_bots:<Includebots(there'salotofthem!)>=False,
# >            types:str<Comma-separatedtypesofeventtoinclude(e.gPushEvent)>='', p
# >            ause:float<NumberofsecondstopausebetweenrequeststotheGitHubapi>=0.4
# >            , filt:_filts<Filteringmethod>=None,
# >            filtval:str<Valuetofilterby(for`repo`useformat`owner/repo`)>=None)

# %%
#| include: false
from nbdev import nbdev_export
nbdev_export()
# Out:
# Converted 00_ghtop.ipynb.
# Converted index.ipynb.
# Converted richext.ipynb.
